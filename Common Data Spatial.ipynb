# %% [markdown]
# # Common Data Spatial

# %% [markdown]
# Matplotlib sebagai tool untuk visualisasi

# %%
import numpy as np
np.random.seed(1)
array = np.random.randint(100, 200, size=(4, 5))
array
# Out:
# array([[137, 112, 172, 109, 175],
#        [105, 179, 164, 116, 101],
#        [176, 171, 106, 125, 150],
#        [120, 118, 184, 111, 128]])

# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
data_url ='https://visdatasets.github.io/datasets/gapminder.csv'

df = pd.read_csv(data_url)

# %%
df
# Out:
#                    Country  LifeExpectancy  FertilityRate Population  \
# 0              Afghanistan          51.000           7.81   19701940
# 1                  Albania          74.200           2.47    3121965
# 2                  Algeria          73.200           2.63   31183658
# 3                   Angola          52.600           6.88   15058638
# 4      Antigua and Barbuda          73.900           2.32      77648
# ..                     ...             ...            ...        ...
# 186  Virgin Islands (U.S.)          79.247           2.13     108511
# 187     West Bank and Gaza          73.500           5.57    3223781
# 188         Western Sahara          66.507           3.04     305615
# 189                 Zambia          45.700           6.10   10585220
# 190               Zimbabwe          50.800           4.11   12499981
#
#                          Region
# 0                    South Asia
# 1         Europe & Central Asia
# 2    Middle East & North Africa
# ...

# %%
df.loc[155]
# Out:
# Country                      Somalia
# LifeExpectancy                  54.3
# FertilityRate                   7.65
# Population                   7385416
# Region            Sub-Saharan Africa
# Name: 155, dtype: object

# %%
df['Country']
# Out:
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                     Angola
# 4        Antigua and Barbuda
#                ...
# 186    Virgin Islands (U.S.)
# 187       West Bank and Gaza
# 188           Western Sahara
# 189                   Zambia
# 190                 Zimbabwe
# Name: Country, Length: 191, dtype: object

# %%
# Scatterplot 3
plt.scatter(df.LifeExpectancy, df.FertilityRate,  c = 'blue', edgecolor = 'darkblue')
plt.grid()
plt.xlabel('Life Expectancy')
plt.ylabel('Fertility Rate')
plt.title('Fertility Rate as a Function of Life Expectancy')

# Show your plot
plt.show()

# %%
lebih_dari_70 = df[df['LifeExpectancy'] > 70]

# %%
# Scatterplot 3
#plt.style.use("")
plt.scatter(df.LifeExpectancy, df.FertilityRate,  c = 'blue', edgecolor = 'darkblue', label = '< 70')
plt.scatter(lebih_dari_70.LifeExpectancy, lebih_dari_70.FertilityRate,  c = 'red', edgecolor = 'darkblue', label = '> 70')
lebih_dari_70
plt.legend()
plt.grid()
plt.xlabel('Life Expectancy')
plt.ylabel('Fertility Rate')
plt.title('Fertility Rate as a Function of Life Expectancy')

# Show your plot
plt.show()

# %%
#plt.style.available

# %%
df = pd.read_csv('./countries.csv')
df
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 239      YE  15.552727  48.516388                 Yemen
# 240      YT -12.827500  45.166244               Mayotte
# 241      ZA -30.559482  22.937506          South Africa
# 242      ZM -13.133897  27.849332                Zambia
# 243      ZW -19.015438  29.154857              Zimbabwe
#
# [244 rows x 4 columns]

# %%
# print the first few rows of df 
print(df.head())
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
# Plot the locations
plt.scatter(x = df.longitude, y = df.latitude)

# Show the plot
plt.show()

# %% [markdown]
# # Geometries dan shapefiles

# %%
import sys
'geopandas' in sys.modules
# Out:
# True

# %%
# Import geopandas
import geopandas as gpd 

# Read in the countries shapefile and look at the first few rows.
country = gpd.read_file('./bhutan/bhutan.shp')
print(country.head())
# Out:
#         NAM  Shape_Leng  Shape_Area  \
# 0  Bumthang    2.688277    0.248579
# 1   Chhukha    2.522871    0.170895
# 2    Dagana    2.275020    0.156650
# 3      Gasa    3.421569    0.287546
# 4       Haa    2.137497    0.173650
#
#                                             geometry
# 0  POLYGON ((90.69793 28.07901, 90.69972 28.07863...
# 1  POLYGON ((89.57479 27.26339, 89.57630 27.26308...
# 2  POLYGON ((89.76770 27.27966, 89.77453 27.27906...
# 3  POLYGON ((89.80424 28.23884, 89.80621 28.23771...
# 4  POLYGON ((89.14211 27.60441, 89.14596 27.60251...

# %%
# Print the contents of the countries geometry in the first row
print(country.loc[0, 'geometry'])
# Out:
# POLYGON ((90.69792596200006 28.079014597000025, 90.69972294400009 28.07863025300003, 90.70044538000008 28.075624722000043, 90.70201888400004 28.07364668200006, 90.70380495700005 28.071480258000065, 90.70506851300007 28.070442666000076, 90.70654782700007 28.07015455900006, 90.70866133200008 28.069955935000053, 90.70971337300006 28.069295148000037, 90.71161934900005 28.06928596000006, 90.71415698400006 28.069367364000072, 90.71564030800005 28.069734872000026, 90.71712248300008 28.069915020000053, 90.71839171200008 28.069815165000023, 90.71922626300005 28.069793038000057, 90.72039831900008 28.069618023000032, 90.72145633200006 28.06951917300006, 90.72240804800003 28.06951451300006, 90.72335976500005 28.069509846000074, 90.72441952900004 28.06969199300005, 90.72507052800006 28.06961768900004, 90.72579014300004 28.069122071000038, 90.72614117100005 28.068285165000077, 90.72613840100007 28.067842760000076, 90.72613440900005 28.06720511000003, 90.72642269700003 28.066103286000043, 90.727326
# ...

# %%
type(country.loc[0, 'geometry'])
# Out:
# shapely.geometry.polygon.Polygon

# %%
import matplotlib.pyplot as plt
plt.style.use('default')

# Plot the country without any additional arguments
country.plot()
plt.show()

# %%
country.columns
# Out:
# Index(['NAM', 'Shape_Leng', 'Shape_Area', 'geometry'], dtype='object')

# %%
country.plot(column = 'NAM')
# Out:
# <Axes: >

# %%
country.plot(column = 'NAM', legend = True)
plt.show()

# %% [markdown]
# # Scatterplot di atas Polygon

# %%
schools = gpd.read_file('./bhutan_schools/bhutan_schools.shp')
schools
# Out:
#                Name   Latitude  Longitude                   geometry
# 0         Jakar HSS  27.546633  90.741479  POINT (90.74148 27.54663)
# 1     W/Choling LSS  27.551144  90.749585  POINT (90.74959 27.55114)
# 2    Gangrithang PS  27.547005  90.762306  POINT (90.76231 27.54701)
# 3    Zangtherpo CPS  27.594233  90.726850  POINT (90.72685 27.59423)
# 4       Kharsat CPS  27.629839  90.717084  POINT (90.71708 27.62984)
# ..              ...        ...        ...                        ...
# 857   Mewangang NFE  26.984421  90.936585  POINT (90.93659 26.98442)
# 858      Bobsar NFE  26.957874  90.868437  POINT (90.86844 26.95787)
# 859      Panabi NFE  26.948301  90.856974  POINT (90.85697 26.94830)
# 860    Barpong  NFE  26.936689  91.117442  POINT (91.11744 26.93669)
# 861     Panbang NFE  26.847753  90.961914  POINT (90.96191 26.84775)
#
# [862 rows x 4 columns]

# %%
country.plot(column = 'NAM')

plt.scatter(x = schools.Longitude, y = schools.Latitude, c = 'black')

plt.show()

# %%
deletion_list = [69, 71, 98, 99, 104, 426]

# %%
schools_edited = schools.drop(deletion_list)

# %%
schools_edited
# Out:
#                Name   Latitude  Longitude                   geometry
# 0         Jakar HSS  27.546633  90.741479  POINT (90.74148 27.54663)
# 1     W/Choling LSS  27.551144  90.749585  POINT (90.74959 27.55114)
# 2    Gangrithang PS  27.547005  90.762306  POINT (90.76231 27.54701)
# 3    Zangtherpo CPS  27.594233  90.726850  POINT (90.72685 27.59423)
# 4       Kharsat CPS  27.629839  90.717084  POINT (90.71708 27.62984)
# ..              ...        ...        ...                        ...
# 857   Mewangang NFE  26.984421  90.936585  POINT (90.93659 26.98442)
# 858      Bobsar NFE  26.957874  90.868437  POINT (90.86844 26.95787)
# 859      Panabi NFE  26.948301  90.856974  POINT (90.85697 26.94830)
# 860    Barpong  NFE  26.936689  91.117442  POINT (91.11744 26.93669)
# 861     Panbang NFE  26.847753  90.961914  POINT (90.96191 26.84775)
#
# [856 rows x 4 columns]

# %%
country.plot(column = 'NAM')

plt.scatter(x = schools_edited.Longitude, y = schools_edited.Latitude, c = 'black')

plt.show()

# %%
# Plot the country shapefile
country.plot(column='NAM', legend=True, legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})

# Add the school locations
plt.scatter(x=schools_edited.Longitude, y=schools_edited.Latitude, c='black', edgecolor = 'white')

# Add labels and title
plt.title('Sekolah di Negara Bhutan')
plt.xlabel('Bujur')
plt.ylabel('Lintang')

# Add grid lines and show the plot
plt.grid()
plt.show()

# %%
# COLORMAP

# %%
# Set legend style
lgnd_kwds = {'title': 'Area',
               'loc': 'upper left', 'bbox_to_anchor': (1, 1.03), 'ncol': 1}

# Plot the country using the tab20 colormap (qualitative)
country.plot(column = 'NAM', cmap = 'tab20', legend = True, legend_kwds = lgnd_kwds)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Bhutan')
plt.show()

# %% [markdown]
# # GEOJSON dan Plotting dengan Geopandas

# %%
neighborhoods_path = './geo.json'

# Read in the neighborhoods geojson file
neighborhoods = gpd.read_file(neighborhoods_path)

# Print the first few rows of neighborhoods
print(neighborhoods.head())

# Plot the neighborhoods, color according to name and use the Dark2 colormap
neighborhoods.plot(column = 'neighborhood', cmap = 'Dark2')

# Show the plot.
plt.show()
# Out:
#       neighborhood boroughCode        borough  \
# 0         Allerton           2          Bronx
# 1  Alley Pond Park           4         Queens
# 2    Arden Heights           5  Staten Island
# 3        Arlington           5  Staten Island
# 4         Arrochar           5  Staten Island
#
#                                                  @id  \
# 0  http://nyc.pediacities.com/Resource/Neighborho...
# 1  http://nyc.pediacities.com/Resource/Neighborho...
# 2  http://nyc.pediacities.com/Resource/Neighborho...
# 3  http://nyc.pediacities.com/Resource/Neighborho...
# 4  http://nyc.pediacities.com/Resource/Neighborho...
#
#                                             geometry
# 0  POLYGON ((-73.84860 40.87167, -73.84582 40.870...
# 1  POLYGON ((-73.74333 40.73888, -73.74371 40.739...
# 2  POLYGON ((-74.16983 40.56108, -74.16982 40.561...
# 3  POLYGON ((-74.15975 40.64142, -74.15998 40.641...
# 4  POLYGON ((-74.06078 40.59319, -74.06079 40.593...

# %%
neighborhoods
# Out:
#         neighborhood boroughCode        borough  \
# 0           Allerton           2          Bronx
# 1    Alley Pond Park           4         Queens
# 2      Arden Heights           5  Staten Island
# 3          Arlington           5  Staten Island
# 4           Arrochar           5  Staten Island
# ..               ...         ...            ...
# 305  Windsor Terrace           3       Brooklyn
# 306        Woodhaven           4         Queens
# 307         Woodlawn           2          Bronx
# 308          Woodrow           5  Staten Island
# 309         Woodside           4         Queens
#
#                                                    @id  \
# 0    http://nyc.pediacities.com/Resource/Neighborho...
# 1    http://nyc.pediacities.com/Resource/Neighborho...
# 2    http://nyc.pediacities.com/Resource/Neighborho...
# 3    http://nyc.pediacities.com/Resource/Neighborho...
# 4    http://nyc.pediacities.com/Resource/Neighborho...
# ...

# %%
# Print the first row of neighborhoods GeoDataFrame and the crs
print(neighborhoods.head(1))
print(neighborhoods.crs)

# Convert the crs to epsg:3857
neighborhoods.geometry = neighborhoods.geometry.to_crs(epsg = 3857)
                        
# Print the first row of neighborhoods GeoDataFrame and the crs again
print(neighborhoods.head(1))
print(neighborhoods.crs)
# Out:
#   neighborhood boroughCode borough  \
# 0     Allerton           2   Bronx
#
#                                                  @id  \
# 0  http://nyc.pediacities.com/Resource/Neighborho...
#
#                                             geometry
# 0  POLYGON ((-73.84860 40.87167, -73.84582 40.870...
# EPSG:4326
#   neighborhood boroughCode borough  \
# 0     Allerton           2   Bronx
#
#                                                  @id  \
# 0  http://nyc.pediacities.com/Resource/Neighborho...
#
#                                             geometry
# 0  POLYGON ((-8220788.214 4993431.406, -8220479.3...
# EPSG:3857

# %%
countries = pd.read_csv('./countries.csv')
countries.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
from shapely.geometry import Point

# Print the first few rows of the countries DataFrame
print(countries.head())

# Create a geometry column from longitude & latitude
countries['geometry'] = countries.apply(lambda x: Point(float(x.longitude), float(x.latitude)), axis=1)

# Create a GeoDataFrame from art and verify the type
countries_geo = gpd.GeoDataFrame(countries, crs = neighborhoods.crs, geometry = countries.geometry)
print(type(countries_geo))
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
countries_geo
# Out:
#     country   latitude  longitude                  name  \
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 239      YE  15.552727  48.516388                 Yemen
# 240      YT -12.827500  45.166244               Mayotte
# 241      ZA -30.559482  22.937506          South Africa
# 242      ZM -13.133897  27.849332                Zambia
# 243      ZW -19.015438  29.154857              Zimbabwe
#
#                    geometry
# 0      POINT (1.602 42.546)
# 1     POINT (53.848 23.424)
# 2     POINT (67.710 33.939)
# 3    POINT (-61.796 17.061)
# 4    POINT (-63.069 18.221)
# ..                      ...
# 239   POINT (48.516 15.553)
# 240  POINT (45.166 -12.828)
# ...

# %%
museums = gpd.read_file('./MUSEUM/MUSEUM.shp')

# %%
museums.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# # Mengubah Coordinate Reference System

# %%
museums.geometry = museums.geometry.to_crs(epsg = 3857)

# %%
museums.shape
# Out:
# (130, 8)

# %% [markdown]
# # Spatial Join

# %%
# Spatially join museums and neighborhoods 
museums_intersect_neighborhoods = gpd.sjoin(museums, neighborhoods, op = 'intersects')

# Print the shape property of museums_intersect_neighborhoods
print(museums_intersect_neighborhoods.shape)
# Out:
# (130, 13)
# c:\Users\RIANO\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
bronx = neighborhoods[neighborhoods['borough']=='Bronx']
bronx
# Out:
#            neighborhood boroughCode borough  \
# 0              Allerton           2   Bronx
# 12           Baychester           2   Bronx
# 19              Belmont           2   Bronx
# 38           Bronx Park           2   Bronx
# 39            Bronxdale           2   Bronx
# ..                  ...         ...     ...
# 294           Wakefield           2   Bronx
# 297          West Farms           2   Bronx
# 299  Westchester Square           2   Bronx
# 302      Williamsbridge           2   Bronx
# 307            Woodlawn           2   Bronx
#
#                                                    @id  \
# 0    http://nyc.pediacities.com/Resource/Neighborho...
# 12   http://nyc.pediacities.com/Resource/Neighborho...
# 19   http://nyc.pediacities.com/Resource/Neighborho...
# 38   http://nyc.pediacities.com/Resource/Neighborho...
# 39   http://nyc.pediacities.com/Resource/Neighborho...
# ..                                                 ...
# ...

# %%
# Spatially join museums and bronx 
museums_intersect_bronx = gpd.sjoin(museums, bronx, op = 'intersects')

# Print the shape property of art_intersect_neighborhoods
print(museums_intersect_bronx.shape)
# Out:
# (8, 13)
# c:\Users\RIANO\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
museums_intersect_bronx
# Out:
#                                   NAME             TEL  \
# 11                 Bartow-Pell Mansion  (718) 885-1461
# 13    Bronx Historical Society & Musem  (718) 881-8900
# 119             Valentine-Varian House  (718) 881-8900
# 14     Bronx Museum of the Arts (BXMA)  (718) 681-6000
# 38    Hall Of Fame For Great Americans  (718) 289-5161
# 41   Holocaust Museum & Studies Center  (718) 817-7700
# 120         Van Cortlandt House Museum  (718) 543-3344
# 121                          Wave Hill  (718) 549-3200
#
#                                                    URL  \
# 11        http://bartowpellmansionmuseum.org/index.php
# 13              http://www.bronxhistoricalsociety.org/
# 119  http://www.museumregister.com/US/NewYork/Bronx...
# 14                         http://www.bronxmuseum.org/
# 38                 http://www.bcc.cuny.edu/hallofFame/
# 41                    http://www.holocauststudies.org/
# 120                  http://www.vancortlandthouse.org/
# ...

# %% [markdown]
# # Agregasi Points di Dalam Polygon

# %%
museums
# Out:
#                                                NAME             TEL  \
# 0              Alexander Hamilton U.S. Custom House  (212) 514-3700
# 1                         Alice Austen House Museum  (718) 816-4506
# 2              American Academy of Arts and Letters  (212) 368-5900
# 3                          American Folk Art Museum  (212) 265-1040
# 4               American Immigration History Center  (212) 363-3200
# ..                                              ...             ...
# 125  American Sephardi Federation / Sephardic House  (212) 294-8350
# 126              YIVO Institute for Jewish Research  (212) 246-6860
# 127              American Jewish Historical Society  (212) 294-6160
# 128                       Yeshiva University Museum  (212) 294-8330
# 129                       Center For Jewish History  (212) 294-8301
#
#                                             URL              ADRESS1 ADDRESS2  \
# ...

# %%
# Get name and city from museums and group by city
museums_grouped = museums[['NAME', 'CITY']].groupby('CITY')

# Aggregate the grouped data and count the museums within each city
print(museums_grouped.agg('count').sort_values(by = 'NAME', ascending = False))
# Out:
#                   NAME
# CITY
# New York            89
# Brooklyn            12
# Queens              10
# Staten Island        9
# Bronx                8
# Jackson Heights      1
# Long Island City     1

# %%
# Create bronx_art from museums where the museums city is Bronx
bronx_art = museums.loc[museums.CITY == "Bronx"]

# Get just the Bronx neighborhood polygon and save it as bronx_polygon
bronx_polygon = neighborhoods.loc[neighborhoods.borough == "Bronx"]

# Plot the bronx_polygon as ax 
ax = bronx_polygon.plot(color = 'lightgreen')

lgnd_kwds = {'loc': 'upper left', 'bbox_to_anchor': (1, 1.05), 'ncol': 1}

# Add a plot of the bronx_art and show it
bronx_art.plot( ax = ax, column = 'ADRESS1', legend = True, legend_kwds = lgnd_kwds)
plt.show()

# %%
bronx_art
# Out:
#                                   NAME             TEL  \
# 11                 Bartow-Pell Mansion  (718) 885-1461
# 13    Bronx Historical Society & Musem  (718) 881-8900
# 14     Bronx Museum of the Arts (BXMA)  (718) 681-6000
# 38    Hall Of Fame For Great Americans  (718) 289-5161
# 41   Holocaust Museum & Studies Center  (718) 817-7700
# 119             Valentine-Varian House  (718) 881-8900
# 120         Van Cortlandt House Museum  (718) 543-3344
# 121                          Wave Hill  (718) 549-3200
#
#                                                    URL  \
# 11        http://bartowpellmansionmuseum.org/index.php
# 13              http://www.bronxhistoricalsociety.org/
# 14                         http://www.bronxmuseum.org/
# 38                 http://www.bcc.cuny.edu/hallofFame/
# 41                    http://www.holocauststudies.org/
# 119  http://www.museumregister.com/US/NewYork/Bronx...
# 120                  http://www.vancortlandthouse.org/
# ...

# %%
a1 = bronx_polygon.plot(color = 'lightgreen')
bronx_art.plot( ax = a1)
# Out:
# <Axes: >

# %% [markdown]
# # GeoSeries dan Folium

# %%
bronx_polygon.geometry.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
area = bronx_polygon.geometry.area / 10**6
print('The area of the Bronx neighborhood is', area[0], 'km squared')
# Out:
# The area of the Bronx neighborhood is 4.247508150888162 km squared

# %%
bronx_centroid = bronx_polygon.geometry.centroid
bronx_centroid
# Out:
# 0      POINT (-8222055.781 4992409.457)
# 12     POINT (-8219876.099 4993431.794)
# 19     POINT (-8225200.249 4990800.536)
# 38     POINT (-8223777.395 4991378.852)
# 39     POINT (-8222559.350 4990943.080)
#                      ...
# 294    POINT (-8221176.560 4996916.870)
# 297    POINT (-8224228.784 4988975.636)
# 299    POINT (-8220565.626 4988817.852)
# 302    POINT (-8221806.814 4994247.124)
# 307    POINT (-8223228.471 4996419.341)
# Length: 75, dtype: geometry

# %%
bronx_polygon
# Out:
#            neighborhood boroughCode borough  \
# 0              Allerton           2   Bronx
# 12           Baychester           2   Bronx
# 19              Belmont           2   Bronx
# 38           Bronx Park           2   Bronx
# 39            Bronxdale           2   Bronx
# ..                  ...         ...     ...
# 294           Wakefield           2   Bronx
# 297          West Farms           2   Bronx
# 299  Westchester Square           2   Bronx
# 302      Williamsbridge           2   Bronx
# 307            Woodlawn           2   Bronx
#
#                                                    @id  \
# 0    http://nyc.pediacities.com/Resource/Neighborho...
# 12   http://nyc.pediacities.com/Resource/Neighborho...
# 19   http://nyc.pediacities.com/Resource/Neighborho...
# 38   http://nyc.pediacities.com/Resource/Neighborho...
# 39   http://nyc.pediacities.com/Resource/Neighborho...
# ..                                                 ...
# ...

# %%
bronx_polygon['center'] = bronx_centroid
# Out:
# c:\Users\RIANO\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
bronx_polygon
# Out:
#            neighborhood boroughCode borough  \
# 0              Allerton           2   Bronx
# 12           Baychester           2   Bronx
# 19              Belmont           2   Bronx
# 38           Bronx Park           2   Bronx
# 39            Bronxdale           2   Bronx
# ..                  ...         ...     ...
# 294           Wakefield           2   Bronx
# 297          West Farms           2   Bronx
# 299  Westchester Square           2   Bronx
# 302      Williamsbridge           2   Bronx
# 307            Woodlawn           2   Bronx
#
#                                                    @id  \
# 0    http://nyc.pediacities.com/Resource/Neighborho...
# 12   http://nyc.pediacities.com/Resource/Neighborho...
# 19   http://nyc.pediacities.com/Resource/Neighborho...
# 38   http://nyc.pediacities.com/Resource/Neighborho...
# 39   http://nyc.pediacities.com/Resource/Neighborho...
# ..                                                 ...
# ...

# %%
type(museums_intersect_bronx[['NAME','neighborhood']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(museums_intersect_bronx[['NAME','neighborhood','geometry']])
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
art_dist_meters = gpd.sjoin(museums_intersect_bronx[['NAME','neighborhood','geometry']], bronx_polygon)

# %%
art_dist_meters = art_dist_meters[['NAME', 'neighborhood_left', 'geometry', 'center']]
art_dist_meters
# Out:
#                                   NAME   neighborhood_left  \
# 11                 Bartow-Pell Mansion     Pelham Bay Park
# 13    Bronx Historical Society & Musem             Norwood
# 119             Valentine-Varian House             Norwood
# 14     Bronx Museum of the Arts (BXMA)   Concourse Village
# 38    Hall Of Fame For Great Americans  University Heights
# 41   Holocaust Museum & Studies Center         Kingsbridge
# 120         Van Cortlandt House Museum  Van Cortlandt Park
# 121                          Wave Hill           Riverdale
#
#                              geometry                            center
# 11   POINT (-8215999.528 4993447.351)  POINT (-8216262.102 4992987.786)
# 13   POINT (-8224256.010 4994398.122)  POINT (-8224312.166 4994107.665)
# 119  POINT (-8224219.940 4994272.005)  POINT (-8224312.166 4994107.665)
# 14   POINT (-8228708.949 4987450.451)  POINT (-8228400.727 4987092.615)
# 38   POINT (-8228066.575 4991529.176)  POINT (-8227634.208 4991477.258)
# ...

# %%
# Import package for pretty printing
import pprint

# Build a dictionary of NAME and distances for Bronx art
art_distances = {}
for row in art_dist_meters.iterrows():
    vals = row[1]
    key = vals['NAME']
    ctr = vals['center']
    art_distances[key] = vals['geometry'].distance(ctr)

# Print the art_distances
pprint.pprint(art_distances)
# Out:
# {'Bartow-Pell Mansion': 529.2874257014237,
#  'Bronx Historical Society & Musem': 295.8357557169492,
#  'Bronx Museum of the Arts (BXMA)': 472.27907171019433,
#  'Hall Of Fame For Great Americans': 435.47261602866394,
#  'Holocaust Museum & Studies Center': 1101.6024992193222,
#  'Valentine-Varian House': 188.44954871658837,
#  'Van Cortlandt House Museum': 1272.2416186478688,
#  'Wave Hill': 709.1763695918488}

# %%
import folium

# %%
# ! pip install folium

# %%
# Print the head of the urban_polygon
bronx_polygon.head()
# Out:
#    neighborhood boroughCode borough  \
# 0      Allerton           2   Bronx
# 12   Baychester           2   Bronx
# 19      Belmont           2   Bronx
# 38   Bronx Park           2   Bronx
# 39    Bronxdale           2   Bronx
#
#                                                   @id  \
# 0   http://nyc.pediacities.com/Resource/Neighborho...
# 12  http://nyc.pediacities.com/Resource/Neighborho...
# 19  http://nyc.pediacities.com/Resource/Neighborho...
# 38  http://nyc.pediacities.com/Resource/Neighborho...
# 39  http://nyc.pediacities.com/Resource/Neighborho...
#
#                                              geometry  \
# 0   POLYGON ((-8220788.214 4993431.406, -8220479.3...
# 12  POLYGON ((-8218841.338 4992530.085, -8218639.6...
# 19  POLYGON ((-8224359.093 4991295.551, -8224366.7...
# 38  POLYGON ((-8223164.965 4991107.997, -8223015.9...
# 39  POLYGON ((-8223046.308 4991304.866, -8221655.5...
#
#                               center
# 0   POINT (-8222055.781 4992409.457)
# ...

# %%
bronx_polygon.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bronx_polygon = bronx_polygon.to_crs(epsg = 4326)
bronx_polygon.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bronx_centroid = bronx_polygon.geometry.centroid
bronx_polygon['center'] = bronx_centroid
bronx_polygon
# Out:
# C:\Users\RIANO\AppData\Local\Temp\ipykernel_17372\2188390251.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   bronx_centroid = bronx_polygon.geometry.centroid
#            neighborhood boroughCode borough  \
# 0              Allerton           2   Bronx
# 12           Baychester           2   Bronx
# 19              Belmont           2   Bronx
# 38           Bronx Park           2   Bronx
# 39            Bronxdale           2   Bronx
# ..                  ...         ...     ...
# 294           Wakefield           2   Bronx
# 297          West Farms           2   Bronx
# 299  Westchester Square           2   Bronx
# 302      Williamsbridge           2   Bronx
# 307            Woodlawn           2   Bronx
#
#                                                    @id  \
# 0    http://nyc.pediacities.com/Resource/Neighborho...
# ...

# %%
# Create allerton_center from the urban_polygon center
allerton_center = bronx_polygon.center[0]

# Print allerton_center
print(allerton_center)

# Create array for folium called allerton_location
allerton_location = [allerton_center.y, allerton_center.x]

# Print urban_location
print(allerton_location)
# Out:
# POINT (-73.85998385871085 40.86472734471021)
# [40.86472734471021, -73.85998385871085]

# %%
# Construct a folium map with allerton_location
downtown_map = folium.Map(location = allerton_location, zoom_start = 12)

# Display the map
display(downtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Draw our neighborhood: Bronx
folium.GeoJson(bronx_polygon.geometry).add_to(downtown_map)

# Display the map
display(downtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Iterate through the art_dist_meters and print each part of tuple returned
for row in art_dist_meters.iterrows():
    print('first part: ', row[0])
    print('second part: ', row[1])
# Out:
# first part:  11
# second part:  NAME                                           Bartow-Pell Mansion
# neighborhood_left                                  Pelham Bay Park
# geometry             POINT (-73.80557949995749 40.871778316782866)
# center                POINT (-8216262.101922531 4992987.786399837)
# Name: 11, dtype: object
# first part:  13
# second part:  NAME                              Bronx Historical Society & Musem
# neighborhood_left                                          Norwood
# geometry             POINT (-73.87974874003552 40.878236441349095)
# center               POINT (-8224312.166021612 4994107.6654887805)
# Name: 13, dtype: object
# first part:  119
# second part:  NAME                                        Valentine-Varian House
# neighborhood_left                                          Norwood
# geometry              POINT (-73.87942471849588 40.87737982466886)
# center               POINT (-8224312.166021612 4994107.6654887805)
# ...

# %%
art_dist_meters = art_dist_meters.to_crs(epsg = 4326)

# %%
# Create a location and marker with each iteration for the downtown_map
for row in art_dist_meters.iterrows():
    row_values = row[1].geometry
    location = [row_values.y, row_values.x]
    marker = folium.Marker(location = location)
    marker.add_to(downtown_map)

# Display the map
display(downtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Create popups inside the loop you built to create the markers
for row in art_dist_meters.iterrows():
    row_values = row[1].geometry
    location = [row_values.y, row_values.x]
    popup = (str(row[1].NAME) + " : " + str(row[1].neighborhood_left))
    marker = folium.Marker(location = location, popup = popup)
    marker.add_to(downtown_map)

# Display the map.
display(downtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
